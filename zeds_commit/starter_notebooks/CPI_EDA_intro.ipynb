# %%
import pandas as pd
import seaborn as sns

# %%
#import dataframe
df = pd.read_csv('CPI_Data/Monthly_CPI_data_w_percent_change.csv', index_col = 0)

# %%
df
# Out:
#                                 Food  Food at home  \
# 2012-01                      232.666       231.694
# 2012-02                      232.486       231.180
# 2012-03                      232.792       231.383
# 2012-04                      233.234       231.711
# 2012-05                      233.339       231.518
# ...                              ...           ...
# 2021-10                      284.205       265.478
# 2021-11                      285.507       266.384
# 2021-12                      286.966       267.555
# Annual Percent Change 2021     6.300         6.500
# Monthly Percent Change 2021    0.500         0.400
#
#                              Cereals and bakery products  \
# 2012-01                                          266.677
# 2012-02                                          267.821
# 2012-03                                          267.101
# 2012-04                                          268.014
# 2012-05                                          268.653
# ...

# %%
df.describe()
# Out:
#              Food  Food at home  Cereals and bakery products  \
# count  140.000000    140.000000                   140.000000
# mean   215.795200    207.168950                   235.718329
# std     88.743337     84.845644                    96.515873
# min     -0.200000     -2.000000                    -0.700000
# 25%    236.479750    233.627000                   269.454000
# 50%    247.881500    239.238500                   272.217000
# 75%    256.618250    242.076750                   275.582750
# max    286.966000    267.555000                   297.279000
#
#        Cereals and cereal products  Flour and prepared flour mixes  \
# count                   140.000000                      140.000000
# mean                    198.330729                      208.671407
# std                      81.191139                       85.718224
# min                      -1.600000                       -2.600000
# 25%                     226.808000                      234.793250
# ...

# %% [markdown]
# count row: some lacking values
# row names: have some similarities so what can we do about those? could we condense them? what makes them different

# %% [markdown]
# What are some columns that you all want to look into? Which columns could be a significant factor in driving CPI trends? Which could change first?

# %%
df
# Out:
#                                 Food  Food at home  \
# 2012-01                      232.666       231.694
# 2012-02                      232.486       231.180
# 2012-03                      232.792       231.383
# 2012-04                      233.234       231.711
# 2012-05                      233.339       231.518
# ...                              ...           ...
# 2021-10                      284.205       265.478
# 2021-11                      285.507       266.384
# 2021-12                      286.966       267.555
# Annual Percent Change 2021     6.300         6.500
# Monthly Percent Change 2021    0.500         0.400
#
#                              Cereals and bakery products  \
# 2012-01                                          266.677
# 2012-02                                          267.821
# 2012-03                                          267.101
# 2012-04                                          268.014
# 2012-05                                          268.653
# ...
