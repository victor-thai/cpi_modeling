# %% [markdown]
# # Merge CPI data

# %%
import pandas as pd

# %% [markdown]
# ## Test combining two dataset

# %%
# read excel file and make into df
# december_21 = pd.DataFrame(pd.read_excel('news-release-table1-202112.xlsx', index_col = [0]))
december_21 = pd.DataFrame(pd.read_excel('CPI_data/news-release-table1-202112.xlsx', index_col = [0], header = 3))
november_21 = pd.DataFrame(pd.read_excel('CPI_data/news-release-table1-202111.xlsx', index_col = [0], header = 3))
# Out:
# /Users/victhaaa/opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:214: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
december_21
# Out:
#                                        Expenditure category  \
# Indent Level
# NaN                                                     NaN
# NaN                                                     NaN
# 0.0                                               All items
# 1.0                                                    Food
# 2.0                                            Food at home
# 3.0                             Cereals and bakery products
# 3.0                          Meats, poultry, fish, and eggs
# 3.0                              Dairy and related products
# 3.0                                   Fruits and vegetables
# 3.0           Nonalcoholic beverages and beverage materials
# 3.0                                      Other food at home
# 2.0                                  Food away from home(1)
# 2.0                                                     NaN
# 1.0                                                  Energy
# 2.0                                      Energy commodities
# 3.0                                             Fuel oil(1)
# 3.0                                              Motor fuel
# 4.0                                    Gasoline (all types)
# 2.0                                         Energy services
# 3.0                                             Electricity
# 3.0                             Utility (piped) gas service
# 3.0                                                     NaN
# 1.0                          All items less food and energy
# 2.0            Commodities less food and energy commodities
# 3.0                                                 Apparel
# 3.0                                            New vehicles
# 3.0                                    Used cars and trucks
# 3.0                             Medical care commodities(1)
# 3.0                                     Alcoholic beverages
# 3.0                         Tobacco and smoking products(1)
# 2.0                           Services less energy services
# 3.0                                                 Shelter
# 4.0                               Rent of primary residence
# 4.0                Owners' equivalent rent of residences(2)
# 3.0                                   Medical care services
# 4.0                                 Physicians' services(1)
# 4.0                                    Hospital services(3)
# 3.0                                 Transportation services
# 4.0                 Motor vehicle maintenance and repair(1)
# 4.0                                 Motor vehicle insurance
# 4.0                                           Airline fares
# 4.0                                                     NaN
# 4.0                                              Footnotes:
# 4.0                            (1) Not seasonally adjusted.
# 4.0                (2) Indexes on a December 1982=100 base.
# 4.0                (3) Indexes on a December 1996=100 base.
#
#               Relative\nimportance\nNov.\n2021 Unadjusted indexes  Unnamed: 4  \
# Indent Level
# NaN                                        NaN         Dec.\n2020  Nov.\n2021
# NaN                                        NaN                NaN         NaN
# 0.0                                    100.000            260.474     277.948
# 1.0                                     13.990            270.023     285.507
# 2.0                                      7.722            251.253     266.384
# 3.0                                      0.978            283.735     295.909
# 3.0                                      1.840            264.475     299.228
# 3.0                                      0.746             231.74     233.157
# 3.0                                      1.305            306.506     318.436
# 3.0                                      0.909            177.539     185.119
# 3.0                                      1.942            218.534     229.643
# 2.0                                      6.269            299.369     315.481
# 2.0                                        NaN                NaN         NaN
# 1.0                                      7.542            198.155       259.1
# 2.0                                      4.304            198.997     302.635
# 3.0                                      0.114            231.044     333.899
# 3.0                                      4.115            194.996     297.841
# 4.0                                      4.027             193.99     296.571
# 2.0                                      3.238            206.758     227.874
# 3.0                                      2.412            214.375     227.588
# 3.0                                      0.825            180.767     224.225
# 3.0                                        NaN                NaN         NaN
# 1.0                                     78.468            269.226     282.754
# 2.0                                     20.768            145.317     159.426
# 3.0                                      2.669            114.434     122.383
# 3.0                                      3.884            149.091     164.511
# 3.0                                      3.419            150.891     200.209
# 3.0                                      1.487            377.921     379.483
# 3.0                                      0.993            259.397     264.957
# 3.0                                      0.617           1199.508    1298.746
# 2.0                                     57.700            346.808     358.722
# 3.0                                     32.393            327.702     339.997
# 4.0                                      7.583            344.455     354.526
# 4.0                                     23.509            337.695     349.152
# 3.0                                      6.987            564.201     577.076
# 4.0                                      1.777            391.807     408.843
# 4.0                                      2.154            355.232     367.479
# 3.0                                      5.046            312.959     327.749
# 4.0                                      1.080            309.888     325.076
# 4.0                                      1.560            545.376     568.239
# 4.0                                      0.619            205.983     215.159
# 4.0                                        NaN                NaN         NaN
# 4.0                                        NaN                NaN         NaN
# 4.0                                        NaN                NaN         NaN
# 4.0                                        NaN                NaN         NaN
# 4.0                                        NaN                NaN         NaN
#
#               Unnamed: 5 Unadjusted percent change               Unnamed: 7  \
# Indent Level
# NaN           Dec.\n2021   Dec.\n2020-\nDec.\n2021  Nov.\n2021-\nDec.\n2021
# NaN                  NaN                       NaN                      NaN
# 0.0              278.802                         7                      0.3
# 1.0              286.966                       6.3                      0.5
# 2.0              267.555                       6.5                      0.4
# 3.0              297.279                       4.8                      0.5
# 3.0              297.604                      12.5                     -0.5
# 3.0              235.442                       1.6                        1
# 3.0              321.931                         5                      1.1
# 3.0              186.723                       5.2                      0.9
# 3.0              230.809                       5.6                      0.5
# 2.0              317.372                         6                      0.6
# 2.0                  NaN                       NaN                      NaN
# 1.0              256.207                      29.3                     -1.1
# 2.0              296.391                      48.9                     -2.1
# 3.0              325.879                        41                     -2.4
# 3.0               291.51                      49.5                     -2.1
# 4.0              290.185                      49.6                     -2.2
# 2.0              228.199                      10.4                      0.1
# 3.0              227.974                       6.3                      0.2
# 3.0              224.366                      24.1                      0.1
# 3.0                  NaN                       NaN                      NaN
# 1.0              283.908                       5.5                      0.4
# 2.0               160.85                      10.7                      0.9
# 3.0              121.068                       5.8                     -1.1
# 3.0              166.653                      11.8                      1.3
# 3.0              207.164                      37.3                      3.5
# 3.0              379.611                       0.4                        0
# 3.0               265.41                       2.3                      0.2
# 3.0             1308.024                         9                      0.7
# 2.0              359.559                       3.7                      0.2
# 3.0              341.241                       4.1                      0.4
# 4.0              355.931                       3.3                      0.4
# 4.0              350.508                       3.8                      0.4
# 3.0              578.555                       2.5                      0.3
# 4.0              408.644                       4.3                        0
# 4.0              366.854                       3.3                     -0.2
# 3.0              326.063                       4.2                     -0.5
# 4.0              324.688                       4.8                     -0.1
# 4.0              567.875                       4.1                     -0.1
# 4.0              208.954                       1.4                     -2.9
# 4.0                  NaN                       NaN                      NaN
# 4.0                  NaN                       NaN                      NaN
# 4.0                  NaN                       NaN                      NaN
# 4.0                  NaN                       NaN                      NaN
# 4.0                  NaN                       NaN                      NaN
#
#              Seasonally adjusted percent change               Unnamed: 9  \
# Indent Level
# NaN                     Sep.\n2021-\nOct.\n2021  Oct.\n2021-\nNov.\n2021
# NaN                                         NaN                      NaN
# 0.0                                         0.9                      0.8
# 1.0                                         0.9                      0.7
# 2.0                                           1                      0.8
# 3.0                                           1                      0.8
# 3.0                                         1.7                      0.9
# 3.0                                         0.2                      0.2
# 3.0                                         0.1                        1
# 3.0                                         0.8                      0.2
# 3.0                                         1.2                        1
# 2.0                                         0.8                      0.6
# 2.0                                         NaN                      NaN
# 1.0                                         4.8                      3.5
# 2.0                                         6.2                      5.9
# 3.0                                        12.3                      3.5
# 3.0                                         6.1                      6.1
# 4.0                                         6.1                      6.1
# 2.0                                           3                      0.3
# 3.0                                         1.8                      0.3
# 3.0                                         6.6                      0.6
# 3.0                                         NaN                      NaN
# 1.0                                         0.6                      0.5
# 2.0                                           1                      0.9
# 3.0                                           0                      1.3
# 3.0                                         1.4                      1.1
# 3.0                                         2.5                      2.5
# 3.0                                         0.6                      0.1
# 3.0                                        -0.2                        0
# 3.0                                         1.9                      0.9
# 2.0                                         0.4                      0.4
# 3.0                                         0.5                      0.5
# 4.0                                         0.4                      0.4
# 4.0                                         0.4                      0.4
# 3.0                                         0.5                      0.3
# 4.0                                           0                      0.4
# 4.0                                         0.5                     -0.3
# 3.0                                         0.4                      0.7
# 4.0                                         1.5                        0
# 4.0                                           0                     -0.8
# 4.0                                        -0.7                      4.7
# 4.0                                         NaN                      NaN
# 4.0                                         NaN                      NaN
# 4.0                                         NaN                      NaN
# 4.0                                         NaN                      NaN
# 4.0                                         NaN                      NaN
#
#                           Unnamed: 10
# Indent Level
# NaN           Nov.\n2021-\nDec.\n2021
# NaN                               NaN
# 0.0                               0.5
# 1.0                               0.5
# 2.0                               0.4
# 3.0                               0.4
# 3.0                              -0.4
# 3.0                               0.7
# 3.0                               0.9
# 3.0                               0.8
# 3.0                               0.6
# 2.0                               0.6
# 2.0                               NaN
# 1.0                              -0.4
# 2.0                              -0.6
# 3.0                              -2.4
# 3.0                              -0.5
# 4.0                              -0.5
# 2.0                              -0.1
# 3.0                               0.3
# 3.0                              -1.2
# 3.0                               NaN
# 1.0                               0.6
# 2.0                               1.2
# 3.0                               1.7
# 3.0                                 1
# 3.0                               3.5
# 3.0                                 0
# 3.0                               0.5
# 3.0                               0.7
# 2.0                               0.3
# 3.0                               0.4
# 4.0                               0.4
# 4.0                               0.4
# 3.0                               0.3
# 4.0                                 0
# 4.0                               0.2
# 3.0                              -0.3
# 4.0                              -0.1
# 4.0                              -1.5
# 4.0                               2.7
# 4.0                               NaN
# 4.0                               NaN
# 4.0                               NaN
# 4.0                               NaN
# 4.0                               NaN

# %%
#drop null values and empty spaces
december_21 = december_21.dropna()
november_21 = november_21.dropna()
december_21
# Out:
#                                        Expenditure category  \
# Indent Level
# 0.0                                               All items
# 1.0                                                    Food
# 2.0                                            Food at home
# 3.0                             Cereals and bakery products
# 3.0                          Meats, poultry, fish, and eggs
# 3.0                              Dairy and related products
# 3.0                                   Fruits and vegetables
# 3.0           Nonalcoholic beverages and beverage materials
# 3.0                                      Other food at home
# 2.0                                  Food away from home(1)
# 1.0                                                  Energy
# 2.0                                      Energy commodities
# 3.0                                             Fuel oil(1)
# 3.0                                              Motor fuel
# 4.0                                    Gasoline (all types)
# 2.0                                         Energy services
# 3.0                                             Electricity
# 3.0                             Utility (piped) gas service
# 1.0                          All items less food and energy
# 2.0            Commodities less food and energy commodities
# 3.0                                                 Apparel
# 3.0                                            New vehicles
# 3.0                                    Used cars and trucks
# 3.0                             Medical care commodities(1)
# 3.0                                     Alcoholic beverages
# 3.0                         Tobacco and smoking products(1)
# 2.0                           Services less energy services
# 3.0                                                 Shelter
# 4.0                               Rent of primary residence
# 4.0                Owners' equivalent rent of residences(2)
# 3.0                                   Medical care services
# 4.0                                 Physicians' services(1)
# 4.0                                    Hospital services(3)
# 3.0                                 Transportation services
# 4.0                 Motor vehicle maintenance and repair(1)
# 4.0                                 Motor vehicle insurance
# 4.0                                           Airline fares
#
#               Relative\nimportance\nNov.\n2021 Unadjusted indexes Unnamed: 4  \
# Indent Level
# 0.0                                    100.000            260.474    277.948
# 1.0                                     13.990            270.023    285.507
# 2.0                                      7.722            251.253    266.384
# 3.0                                      0.978            283.735    295.909
# 3.0                                      1.840            264.475    299.228
# 3.0                                      0.746             231.74    233.157
# 3.0                                      1.305            306.506    318.436
# 3.0                                      0.909            177.539    185.119
# 3.0                                      1.942            218.534    229.643
# 2.0                                      6.269            299.369    315.481
# 1.0                                      7.542            198.155      259.1
# 2.0                                      4.304            198.997    302.635
# 3.0                                      0.114            231.044    333.899
# 3.0                                      4.115            194.996    297.841
# 4.0                                      4.027             193.99    296.571
# 2.0                                      3.238            206.758    227.874
# 3.0                                      2.412            214.375    227.588
# 3.0                                      0.825            180.767    224.225
# 1.0                                     78.468            269.226    282.754
# 2.0                                     20.768            145.317    159.426
# 3.0                                      2.669            114.434    122.383
# 3.0                                      3.884            149.091    164.511
# 3.0                                      3.419            150.891    200.209
# 3.0                                      1.487            377.921    379.483
# 3.0                                      0.993            259.397    264.957
# 3.0                                      0.617           1199.508   1298.746
# 2.0                                     57.700            346.808    358.722
# 3.0                                     32.393            327.702    339.997
# 4.0                                      7.583            344.455    354.526
# 4.0                                     23.509            337.695    349.152
# 3.0                                      6.987            564.201    577.076
# 4.0                                      1.777            391.807    408.843
# 4.0                                      2.154            355.232    367.479
# 3.0                                      5.046            312.959    327.749
# 4.0                                      1.080            309.888    325.076
# 4.0                                      1.560            545.376    568.239
# 4.0                                      0.619            205.983    215.159
#
#              Unnamed: 5 Unadjusted percent change Unnamed: 7  \
# Indent Level
# 0.0             278.802                         7        0.3
# 1.0             286.966                       6.3        0.5
# 2.0             267.555                       6.5        0.4
# 3.0             297.279                       4.8        0.5
# 3.0             297.604                      12.5       -0.5
# 3.0             235.442                       1.6          1
# 3.0             321.931                         5        1.1
# 3.0             186.723                       5.2        0.9
# 3.0             230.809                       5.6        0.5
# 2.0             317.372                         6        0.6
# 1.0             256.207                      29.3       -1.1
# 2.0             296.391                      48.9       -2.1
# 3.0             325.879                        41       -2.4
# 3.0              291.51                      49.5       -2.1
# 4.0             290.185                      49.6       -2.2
# 2.0             228.199                      10.4        0.1
# 3.0             227.974                       6.3        0.2
# 3.0             224.366                      24.1        0.1
# 1.0             283.908                       5.5        0.4
# 2.0              160.85                      10.7        0.9
# 3.0             121.068                       5.8       -1.1
# 3.0             166.653                      11.8        1.3
# 3.0             207.164                      37.3        3.5
# 3.0             379.611                       0.4          0
# 3.0              265.41                       2.3        0.2
# 3.0            1308.024                         9        0.7
# 2.0             359.559                       3.7        0.2
# 3.0             341.241                       4.1        0.4
# 4.0             355.931                       3.3        0.4
# 4.0             350.508                       3.8        0.4
# 3.0             578.555                       2.5        0.3
# 4.0             408.644                       4.3          0
# 4.0             366.854                       3.3       -0.2
# 3.0             326.063                       4.2       -0.5
# 4.0             324.688                       4.8       -0.1
# 4.0             567.875                       4.1       -0.1
# 4.0             208.954                       1.4       -2.9
#
#              Seasonally adjusted percent change Unnamed: 9 Unnamed: 10
# Indent Level
# 0.0                                         0.9        0.8         0.5
# 1.0                                         0.9        0.7         0.5
# 2.0                                           1        0.8         0.4
# 3.0                                           1        0.8         0.4
# 3.0                                         1.7        0.9        -0.4
# 3.0                                         0.2        0.2         0.7
# 3.0                                         0.1          1         0.9
# 3.0                                         0.8        0.2         0.8
# 3.0                                         1.2          1         0.6
# 2.0                                         0.8        0.6         0.6
# 1.0                                         4.8        3.5        -0.4
# 2.0                                         6.2        5.9        -0.6
# 3.0                                        12.3        3.5        -2.4
# 3.0                                         6.1        6.1        -0.5
# 4.0                                         6.1        6.1        -0.5
# 2.0                                           3        0.3        -0.1
# 3.0                                         1.8        0.3         0.3
# 3.0                                         6.6        0.6        -1.2
# 1.0                                         0.6        0.5         0.6
# 2.0                                           1        0.9         1.2
# 3.0                                           0        1.3         1.7
# 3.0                                         1.4        1.1           1
# 3.0                                         2.5        2.5         3.5
# 3.0                                         0.6        0.1           0
# 3.0                                        -0.2          0         0.5
# 3.0                                         1.9        0.9         0.7
# 2.0                                         0.4        0.4         0.3
# 3.0                                         0.5        0.5         0.4
# 4.0                                         0.4        0.4         0.4
# 4.0                                         0.4        0.4         0.4
# 3.0                                         0.5        0.3         0.3
# 4.0                                           0        0.4           0
# 4.0                                         0.5       -0.3         0.2
# 3.0                                         0.4        0.7        -0.3
# 4.0                                         1.5          0        -0.1
# 4.0                                           0       -0.8        -1.5
# 4.0                                        -0.7        4.7         2.7

# %%
# look at columns in data
december_21.columns
# Out:
# Index(['Expenditure category', 'Relative\nimportance\nNov.\n2021',
#        'Unadjusted indexes', 'Unnamed: 4', 'Unnamed: 5',
#        'Unadjusted percent change', 'Unnamed: 7',
#        'Seasonally adjusted percent change', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
#select which columns to drop
december_columns = december_21.columns[[1,2,3,5,6,7,8,9]]
november_columns = november_21.columns[[1,2,3,5,6,7,8,9]]

#dropping columns
december_21 = december_21.drop(columns = december_columns, axis = 1)
november_21 = november_21.drop(columns = november_columns, axis = 1)

# %%
december_21
# Out:
#                                        Expenditure category Unnamed: 5
# Indent Level
# 0.0                                               All items    278.802
# 1.0                                                    Food    286.966
# 2.0                                            Food at home    267.555
# 3.0                             Cereals and bakery products    297.279
# 3.0                          Meats, poultry, fish, and eggs    297.604
# 3.0                              Dairy and related products    235.442
# 3.0                                   Fruits and vegetables    321.931
# 3.0           Nonalcoholic beverages and beverage materials    186.723
# 3.0                                      Other food at home    230.809
# 2.0                                  Food away from home(1)    317.372
# 1.0                                                  Energy    256.207
# 2.0                                      Energy commodities    296.391
# 3.0                                             Fuel oil(1)    325.879
# 3.0                                              Motor fuel     291.51
# 4.0                                    Gasoline (all types)    290.185
# 2.0                                         Energy services    228.199
# 3.0                                             Electricity    227.974
# 3.0                             Utility (piped) gas service    224.366
# 1.0                          All items less food and energy    283.908
# 2.0            Commodities less food and energy commodities     160.85
# 3.0                                                 Apparel    121.068
# 3.0                                            New vehicles    166.653
# 3.0                                    Used cars and trucks    207.164
# 3.0                             Medical care commodities(1)    379.611
# 3.0                                     Alcoholic beverages     265.41
# 3.0                         Tobacco and smoking products(1)   1308.024
# 2.0                           Services less energy services    359.559
# 3.0                                                 Shelter    341.241
# 4.0                               Rent of primary residence    355.931
# 4.0                Owners' equivalent rent of residences(2)    350.508
# 3.0                                   Medical care services    578.555
# 4.0                                 Physicians' services(1)    408.644
# 4.0                                    Hospital services(3)    366.854
# 3.0                                 Transportation services    326.063
# 4.0                 Motor vehicle maintenance and repair(1)    324.688
# 4.0                                 Motor vehicle insurance    567.875
# 4.0                                           Airline fares    208.954

# %%
#set index
december_21 = december_21.set_index('Expenditure category')
november_21 = november_21.set_index('Expenditure category')
december_21
# Out:
#                                               Unnamed: 5
# Expenditure category
# All items                                        278.802
# Food                                             286.966
# Food at home                                     267.555
# Cereals and bakery products                      297.279
# Meats, poultry, fish, and eggs                   297.604
# Dairy and related products                       235.442
# Fruits and vegetables                            321.931
# Nonalcoholic beverages and beverage materials    186.723
# Other food at home                               230.809
# Food away from home(1)                           317.372
# Energy                                           256.207
# Energy commodities                               296.391
# Fuel oil(1)                                      325.879
# Motor fuel                                        291.51
# Gasoline (all types)                             290.185
# Energy services                                  228.199
# Electricity                                      227.974
# Utility (piped) gas service                      224.366
# All items less food and energy                   283.908
# Commodities less food and energy commodities      160.85
# Apparel                                          121.068
# New vehicles                                     166.653
# Used cars and trucks                             207.164
# Medical care commodities(1)                      379.611
# Alcoholic beverages                               265.41
# Tobacco and smoking products(1)                 1308.024
# Services less energy services                    359.559
# Shelter                                          341.241
# Rent of primary residence                        355.931
# Owners' equivalent rent of residences(2)         350.508
# Medical care services                            578.555
# Physicians' services(1)                          408.644
# Hospital services(3)                             366.854
# Transportation services                          326.063
# Motor vehicle maintenance and repair(1)          324.688
# Motor vehicle insurance                          567.875
# Airline fares                                    208.954

# %%
#rename columns
december_21 = december_21.rename(columns = {'Unnamed: 5': 'Category CPI'})
november_21.columns = ['Category CPI']

# %%
#transpose month df's to make it easier to add into one df
november_21 = november_21.T
december_21 = december_21.T

# %%
combine = december_21.append(november_21)
combine
# Out:
# Expenditure category All items     Food Food at home  \
# Category CPI           278.802  286.966      267.555
# Category CPI           277.948  285.507      266.384
#
# Expenditure category Cereals and bakery products  \
# Category CPI                             297.279
# Category CPI                             295.909
#
# Expenditure category Meats, poultry, fish, and eggs  \
# Category CPI                                297.604
# Category CPI                                299.228
#
# Expenditure category Dairy and related products Fruits and vegetables  \
# Category CPI                            235.442               321.931
# Category CPI                            233.157               318.436
#
# Expenditure category Nonalcoholic beverages and beverage materials  \
# Category CPI                                               186.723
# Category CPI                                               185.119
#
# Expenditure category Other food at home Food away from home(1)  ...  Shelter  \
# Category CPI                    230.809                317.372  ...  341.241
# Category CPI                    229.643                315.481  ...  339.997
#
# Expenditure category Rent of primary residence  \
# Category CPI                           355.931
# Category CPI                           354.526
#
# Expenditure category Owners' equivalent rent of residences(2)  \
# Category CPI                                          350.508
# Category CPI                                          349.152
#
# Expenditure category Medical care services Physicians' services(1)  \
# Category CPI                       578.555                 408.644
# Category CPI                       577.076                 408.843
#
# Expenditure category Hospital services(3) Transportation services  \
# Category CPI                      366.854                 326.063
# Category CPI                      367.479                 327.749
#
# Expenditure category Motor vehicle maintenance and repair(1)  \
# Category CPI                                         324.688
# Category CPI                                         325.076
#
# Expenditure category Motor vehicle insurance Airline fares
# Category CPI                         567.875       208.954
# Category CPI                         568.239       215.159
#
# [2 rows x 37 columns]

# %% [markdown]
# ## Function that combines it together

# %%
#function that combines the datasets
def combine_dataset(xlsx_lst):
    final_df = pd.DataFrame()
    
    #loops thru list of files and gets the CPI for categories
    for xlsx_month in xlsx_lst:
        
        #keep track of month_year in file name
        month_year = xlsx_month[-11:-5:1]
    
        #extra column index and header space
        min_df = pd.DataFrame(pd.read_excel('CPI_data/' + xlsx_month, index_col = [0], header = 3))
        min_df = min_df.dropna()
        
        #drop columns that are not needed
        if len(min_df.columns) < 10:
            min_df_column = min_df.columns[[0,1,2,4,5,6,7,8]]
            min_df = min_df.drop(columns = min_df_column, axis = 1)
            
            #set column name
            min_df.columns = [month_year]
            
        #some cases where there is a missing index column
        else:
            min_df_column = min_df.columns[[1,2,3,5,6,7,8,9]]
            min_df = min_df.drop(columns = min_df_column, axis = 1)
            
            #set index as the expenditure names
            min_df = min_df.set_index('Expenditure category')
            
            #set the columnn name as month and year
            min_df = min_df.rename(columns = {'Unnamed: 5': month_year})
        
        min_dfT = min_df.T
        
        #renaming the columns with parentheses
        #note to self: can improve the time complexity
        col = min_dfT.columns
        df_column_names = []
        for expenditure in col:
            #if there is parentheses, take those out. if not, keep name.
            if ('(' or ')') in expenditure:
                column_name = ''
                for letter in expenditure:
                    if (letter == '('):
                        break
                    else:
                        column_name = column_name + letter
                df_column_names.append(column_name)
            else:
                df_column_names.append(expenditure)
                
        #setting the renamed as columns
        min_dfT.columns = df_column_names
                
        #adding to final dataset
        final_df = final_df.append(min_dfT)
    return final_df

# %%
#function that writes out all the file names with difference in years
def file_writer(year):
    #function that writes file names for a certain year
    lst = []
    for i in range(1,13): 
        
        #files before 2017 have a different file name
        if year < 2017:
            file_path = 'CpiPress1_FINAL_'
            if i < 10:
                
                # zero in front of months with one digit
                file_path = file_path + str(year) + '0' + str(i)
            else:
                file_path = file_path + str(year) + str(i)
            file_path = file_path + '.xlsx'
            lst.append(file_path)
        else:
            
            #file name for files after 2017
            file_path = 'news-release-table1-'
            if i < 10:
                file_path = file_path + str(year) + '0' + str(i)
            else:
                file_path = file_path + str(year) + str(i)
            file_path = file_path + '.xlsx'
            lst.append(file_path)
    return lst

def file_writer_years(start,end):
    #function that writes file names for all years
    lst_year = []
    complete_file_lst = []
    for i in range(start,end):
        lst_year.append(file_writer(i))
        
    #merge nested lists together
    for lst in lst_year:
        for val in lst:
            complete_file_lst.append(val)
    return complete_file_lst

#write file names for 2012 to 2022 (all the data we have)
filename_combine = file_writer_years(2012,2022)

# %%
filename_combine
# Out:
# ['CpiPress1_FINAL_201201.xlsx',
#  'CpiPress1_FINAL_201202.xlsx',
#  'CpiPress1_FINAL_201203.xlsx',
#  'CpiPress1_FINAL_201204.xlsx',
#  'CpiPress1_FINAL_201205.xlsx',
#  'CpiPress1_FINAL_201206.xlsx',
#  'CpiPress1_FINAL_201207.xlsx',
#  'CpiPress1_FINAL_201208.xlsx',
#  'CpiPress1_FINAL_201209.xlsx',
#  'CpiPress1_FINAL_201210.xlsx',
#  'CpiPress1_FINAL_201211.xlsx',
#  'CpiPress1_FINAL_201212.xlsx',
#  'CpiPress1_FINAL_201301.xlsx',
#  'CpiPress1_FINAL_201302.xlsx',
#  'CpiPress1_FINAL_201303.xlsx',
#  'CpiPress1_FINAL_201304.xlsx',
#  'CpiPress1_FINAL_201305.xlsx',
#  'CpiPress1_FINAL_201306.xlsx',
#  'CpiPress1_FINAL_201307.xlsx',
#  'CpiPress1_FINAL_201308.xlsx',
#  'CpiPress1_FINAL_201309.xlsx',
#  'CpiPress1_FINAL_201310.xlsx',
#  'CpiPress1_FINAL_201311.xlsx',
#  'CpiPress1_FINAL_201312.xlsx',
#  'CpiPress1_FINAL_201401.xlsx',
#  'CpiPress1_FINAL_201402.xlsx',
#  'CpiPress1_FINAL_201403.xlsx',
#  'CpiPress1_FINAL_201404.xlsx',
#  'CpiPress1_FINAL_201405.xlsx',
#  'CpiPress1_FINAL_201406.xlsx',
#  'CpiPress1_FINAL_201407.xlsx',
#  'CpiPress1_FINAL_201408.xlsx',
#  'CpiPress1_FINAL_201409.xlsx',
#  'CpiPress1_FINAL_201410.xlsx',
#  'CpiPress1_FINAL_201411.xlsx',
#  'CpiPress1_FINAL_201412.xlsx',
#  'CpiPress1_FINAL_201501.xlsx',
#  'CpiPress1_FINAL_201502.xlsx',
#  'CpiPress1_FINAL_201503.xlsx',
#  'CpiPress1_FINAL_201504.xlsx',
#  'CpiPress1_FINAL_201505.xlsx',
#  'CpiPress1_FINAL_201506.xlsx',
#  'CpiPress1_FINAL_201507.xlsx',
#  'CpiPress1_FINAL_201508.xlsx',
#  'CpiPress1_FINAL_201509.xlsx',
#  'CpiPress1_FINAL_201510.xlsx',
#  'CpiPress1_FINAL_201511.xlsx',
#  'CpiPress1_FINAL_201512.xlsx',
#  'CpiPress1_FINAL_201601.xlsx',
#  'CpiPress1_FINAL_201602.xlsx',
#  'CpiPress1_FINAL_201603.xlsx',
#  'CpiPress1_FINAL_201604.xlsx',
#  'CpiPress1_FINAL_201605.xlsx',
#  'CpiPress1_FINAL_201606.xlsx',
#  'CpiPress1_FINAL_201607.xlsx',
#  'CpiPress1_FINAL_201608.xlsx',
#  'CpiPress1_FINAL_201609.xlsx',
#  'CpiPress1_FINAL_201610.xlsx',
#  'CpiPress1_FINAL_201611.xlsx',
#  'CpiPress1_FINAL_201612.xlsx',
#  'news-release-table1-201701.xlsx',
#  'news-release-table1-201702.xlsx',
#  'news-release-table1-201703.xlsx',
#  'news-release-table1-201704.xlsx',
#  'news-release-table1-201705.xlsx',
#  'news-release-table1-201706.xlsx',
#  'news-release-table1-201707.xlsx',
#  'news-release-table1-201708.xlsx',
#  'news-release-table1-201709.xlsx',
#  'news-release-table1-201710.xlsx',
#  'news-release-table1-201711.xlsx',
#  'news-release-table1-201712.xlsx',
#  'news-release-table1-201801.xlsx',
#  'news-release-table1-201802.xlsx',
#  'news-release-table1-201803.xlsx',
#  'news-release-table1-201804.xlsx',
#  'news-release-table1-201805.xlsx',
#  'news-release-table1-201806.xlsx',
#  'news-release-table1-201807.xlsx',
#  'news-release-table1-201808.xlsx',
#  'news-release-table1-201809.xlsx',
#  'news-release-table1-201810.xlsx',
#  'news-release-table1-201811.xlsx',
#  'news-release-table1-201812.xlsx',
#  'news-release-table1-201901.xlsx',
#  'news-release-table1-201902.xlsx',
#  'news-release-table1-201903.xlsx',
#  'news-release-table1-201904.xlsx',
#  'news-release-table1-201905.xlsx',
#  'news-release-table1-201906.xlsx',
#  'news-release-table1-201907.xlsx',
#  'news-release-table1-201908.xlsx',
#  'news-release-table1-201909.xlsx',
#  'news-release-table1-201910.xlsx',
#  'news-release-table1-201911.xlsx',
#  'news-release-table1-201912.xlsx',
#  'news-release-table1-202001.xlsx',
#  'news-release-table1-202002.xlsx',
#  'news-release-table1-202003.xlsx',
#  'news-release-table1-202004.xlsx',
#  'news-release-table1-202005.xlsx',
#  'news-release-table1-202006.xlsx',
#  'news-release-table1-202007.xlsx',
#  'news-release-table1-202008.xlsx',
#  'news-release-table1-202009.xlsx',
#  'news-release-table1-202010.xlsx',
#  'news-release-table1-202011.xlsx',
#  'news-release-table1-202012.xlsx',
#  'news-release-table1-202101.xlsx',
#  'news-release-table1-202102.xlsx',
#  'news-release-table1-202103.xlsx',
#  'news-release-table1-202104.xlsx',
#  'news-release-table1-202105.xlsx',
#  'news-release-table1-202106.xlsx',
#  'news-release-table1-202107.xlsx',
#  'news-release-table1-202108.xlsx',
#  'news-release-table1-202109.xlsx',
#  'news-release-table1-202110.xlsx',
#  'news-release-table1-202111.xlsx',
#  'news-release-table1-202112.xlsx']

# %%
merge_data = combine_dataset(data_combine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ebdd388f3f4a> in <module>
# ----> 1 merge_data = combine_dataset(data_combine)
#
# NameError: name 'data_combine' is not defined

# %%
#merged dataset, NOT cleaned
merge_data

# %%
merge_data.columns
