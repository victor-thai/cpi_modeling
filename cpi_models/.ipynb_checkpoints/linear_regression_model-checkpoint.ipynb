# 2012-01-01                               125.629                   391.382
# 2012-02-01                               126.180                   391.236
# 2012-03-01                               126.107                   392.364
# 2012-04-01                               126.114                   393.320
# 2012-05-01                               125.905                   392.859
# ...                                          ...                       ...
# 2021-08-01                               132.076                   479.048
# 2021-09-01                               133.462                   479.525
# 2021-10-01                               134.745                   483.592
# 2021-11-01                               135.345                   484.683
# 2021-12-01                               136.787                   487.131
#
#             Personal care  Recorded music and music subscriptions  \
# 2012-01-01        210.299                                  89.691
# 2012-02-01        210.330                                  89.896
# 2012-03-01        211.289                                  89.704
# 2012-04-01        211.865                                  89.084
# 2012-05-01        211.649                                  88.904
# ...                   ...                                     ...
# 2021-08-01        244.968                                  79.549
# 2021-09-01        244.840                                  79.820
# 2021-10-01        246.307                                  79.954
# 2021-11-01        246.445                                  79.385
# 2021-12-01        247.561                                  79.733
#
#             Men's underwear, nightwear, swimwear, and accessories  All items
# 2012-01-01                                            148.547        227.842
# 2012-02-01                                            148.183        228.329
# 2012-03-01                                            149.106        228.807
# 2012-04-01                                            150.584        229.187
# 2012-05-01                                            155.044        228.713
# ...                                                       ...            ...
# 2021-08-01                                            167.846        273.092
# 2021-09-01                                            168.872        274.214
# 2021-10-01                                            170.986        276.590
# 2021-11-01                                            170.751        278.524
# 2021-12-01                                            167.052        280.126
#
# [120 rows x 314 columns]

# %%
# nulls of ppi data
ppi = pd.read_csv('../CPI_Data/PPI_data.csv', index_col = 0).T
for i in ppi.isna().sum():
    print(i)
# Out:
# 1006
# 1006
# 1006
# 252
# 252
# 0
# 791
# 252
# 252
# 701
# 713
# 252
# 252
# 252
# 348
# 252
# 0
# 0
# 623
# 0
# 749
# 252
# 492
# 1006
# 540
# 779
# 779
# 252
# 588
# 565
# 1006
# 252
# 716
# 935
# 935
# 252
# 0
# 84
# 905
# 84
# 689
# 252
# 156
# 971
# 252
# 576
# 163
# 528
# 528
# 665
# 252
# 252
# 779
# 419
# 677
# 419
# 252
# 719
# 479
# 540
# 252
# 252
# 252
# 0
# 252
# 0
# 252
# 252
# 252
# 1079
# 132
# 456
# 456
# 492
# 653
# 701
# 540
# 719
# 420
# 252
# 252
# 0
# 660
# 629
# 635
# 635
# 1006
# 1006
# 1029
# 998
# 998
# 998
# 998
# 1001
# 998
# 998
# 1001
# 998
# 998
# 1001
# 1034
# 998
# 998
# 998
# 998
# 998
# 998
# 998
# 1001
# 998
# 998
# 1006
# 995
# 1001
# 995
# 1001
# 995
# 995
# 1006
# 659
# 1001
# 1001
# 1001
# 1001
# 998
# 995
# 998
# 1031
# 1001
# 999
# 999
# 1001
# 995
# 998
# 998
# 998
# 998
# 998
# 995
# 998
# 998
# 999
# 1001
# 1001
# 1001
# 995
# 995
# 998
# 998
# 995
# 995
# 1013
# 995
# 995
# 1047
# 1001
# 1001
# 995
# 1001
# 995
# 995
# 713
# 1006
# 947
# 959
# 965
# 977
# 1037

# %%
#cant have null values in our model
df = df.dropna(axis = 1)
df
# Out:
#                Food  Food at home  Cereals and bakery products  \
# 2012-01-01  232.666       231.694                      266.677
# ...                                          ...                       ...
# 2021-08-01                               132.076                   479.048
# 2021-09-01                               133.462                   479.525
# 2021-10-01                               134.745                   483.592
# 2021-11-01                               135.345                   484.683
# 2021-12-01                               136.787                   487.131
#
#             Personal care  Recorded music and music subscriptions  \
# 2012-01-01        210.299                                  89.691
# 2012-02-01        210.330                                  89.896
# 2012-03-01        211.289                                  89.704
# 2012-04-01        211.865                                  89.084
# 2012-05-01        211.649                                  88.904
# ...                   ...                                     ...
# 2021-08-01        244.968                                  79.549
# 2021-09-01        244.840                                  79.820
# 2021-10-01        246.307                                  79.954
# 2021-11-01        246.445                                  79.385
# 2021-12-01        247.561                                  79.733
#
#             Men's underwear, nightwear, swimwear, and accessories  All items
# 2012-01-01                                            148.547        227.842
# 2012-02-01                                            148.183        228.329
# 2012-03-01                                            149.106        228.807
# 2012-04-01                                            150.584        229.187
# 2012-05-01                                            155.044        228.713
# ...                                                       ...            ...
# 2021-08-01                                            167.846        273.092
# 2021-09-01                                            168.872        274.214
# 2021-10-01                                            170.986        276.590
# 2021-11-01                                            170.751        278.524
# 2021-12-01                                            167.052        280.126
#
# [120 rows x 305 columns]

# %%
#change index to datetime
df.index = pd.to_datetime(df.index)

# %%
# all the columns that we have in df
for i in df.columns:
    print(i)
# Out:
# Food
# Food at home
# Cereals and bakery products
# Cereals and cereal products
# Flour and prepared flour mixes
# Breakfast cereal
# Rice, pasta, cornmeal
# Bakery products
# Bread
# Fresh biscuits, rolls, muffins
# Cakes, cupcakes, and cookies
# Other bakery products
# Meats, poultry, fish, and eggs
# Meats, poultry, and fish
# Meats
# Beef and veal
# Uncooked ground beef
# Uncooked beef roasts
# Uncooked beef steaks
# Uncooked other beef and veal
# Pork
# Bacon, breakfast sausage, and related products
# Ham
# Pork chops
# Other pork including roasts and picnics
# Other meats
# Poultry
# Chicken
# Other poultry including turkey
# Fish and seafood
# Fresh fish and seafood
# Processed fish and seafood
# Eggs
# Dairy and related products
# Milk
# Cheese and related products
# Ice cream and related products
# Other dairy and related products
# Fruits and vegetables
# Fresh fruits and vegetables
# Fresh fruits
# Apples
# Bananas
# Citrus fruits
# Other fresh fruits
# Fresh vegetables
# Potatoes
# Lettuce
# Tomatoes
# Other fresh vegetables
# Processed fruits and vegetables
# Canned fruits and vegetables
# Frozen fruits and vegetables
# Other processed fruits and vegetables including dried
# Nonalcoholic beverages and beverage materials
# Juices and nonalcoholic drinks
# Carbonated drinks
# Frozen noncarbonated juices and drinks
# Nonfrozen noncarbonated juices and drinks
# Beverage materials including coffee and tea
# Coffee
# Other beverage materials including tea
# Other food at home
# Sugar and sweets
# Sugar and artificial sweeteners
# Candy and chewing gum
# Other sweets
# Fats and oils
# Butter and margarine
# Salad dressing
# Other fats and oils including peanut butter
# Other foods
# Soups
# Frozen and freeze dried prepared foods
# Snacks
# Spices, seasonings, condiments, sauces
# Baby food
# Other miscellaneous foods
# Food away from home
# Full service meals and snacks
# Limited service meals and snacks
# Food from vending machines and mobile vendors
# Other food away from home
# Energy
# Intracity transportation
# Recreation services
# Video and audio services
# Cable and satellite television and radio service
# Video discs and other media, including rental of video and audio
# Pet services including veterinary
# Photographers and film processing
# Other recreation services
# Club dues and fees for participant sports and group exercises
# Admissions
# Education and communication services
# Tuition, other school fees, and childcare
# College tuition and fees
# Elementary and high school tuition and fees
# Child care and nursery school
# Technical and business school tuition and fees
# Postage and delivery services
# Postage
# Delivery services
# Telephone services
# Wireless telephone services
# Land-line telephone services
# Internet services and electronic information providers
# Other personal services
# Personal care services
# Haircuts and other personal care services
# Miscellaneous personal services
# Legal services
# Funeral expenses
# Laundry and dry cleaning services
# Apparel services other than laundry and dry cleaning
# Financial services
# All items less food
# All items less shelter
# All items less food and shelter
# All items less food, shelter, and energy
# All items less food, shelter, energy, and used cars and trucks
# All items less medical care
# All items less energy
# Commodities
# Commodities less food, energy, and used cars and trucks
# Commodities less food
# Commodities less food and beverages
# Services
# Services less rent of shelter
# Services less medical care services
# Durables
# Nondurables
# Nondurables less food
# Nondurables less food and beverages
# Nondurables less food, beverages, and apparel
# Nondurables less food and apparel
# Housing
# Education and communication
# Education
# Communication
# Information and information processing
# Information technology, hardware and services
# Recreation
# Video and audio
# Pets, pet products and services
# Photography
# Food and beverages
# Domestically produced farm food
# Other services
# Apparel less footwear
# Fuels and utilities
# Household energy
# Medical care
# Transportation
# Private transportation
# New and used motor vehicles
# Utilities and public transportation
# Household furnishings and operations
# Other goods and services
# Personal care
# Recorded music and music subscriptions
# Men's underwear, nightwear, swimwear, and accessories
# All items

# %%
#create x and y variables
x = df.drop(columns = ['All items less food','All items less shelter','All items less food and shelter',
                        'All items less food, shelter, and energy','All items less food, shelter, energy, and used cars and trucks',
                       'All items less medical care','All items less energy'], axis = 1)
y = df['All items less food']

# %%
#just the essential expenditure categories
x = df[['Food and beverages','Housing','Apparel','Transportation',
        'Medical care','Recreation','Education and communication',
        'Other goods and services']]

y = df['All items less food']

# %%
#split data into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, shuffle = False)

# %%
# linear regression object
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x_test)

# %%
y_test.index[0]
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
y_predict
# Out:
# array([257.55306166, 258.27974577, 257.53880399, 255.01021371,
#        254.69468311, 256.13904846, 257.77501184, 258.59969156,
#        259.01863724, 258.98411372, 258.86943427, 259.03337473,
#        260.23263103, 261.75865433, 263.76784507, 265.93717886,
#        268.13187706, 270.60719439, 271.78095786, 272.2630814 ,
#        272.76737494, 274.93227243, 276.28365304, 277.08117546])

# %%
predict_date = pd.date_range(y_test.index[0], y_test.index[-1], freq = '1MS')
predict_date
# Out:
# DatetimeIndex(['2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
predictions = pd.Series(y_predict, index = predict_date)
predictions
# Out:
# 2020-01-01    257.553062
# 2020-02-01    258.279746
# 2020-03-01    257.538804
# 2020-04-01    255.010214
# 2020-05-01    254.694683
# 2020-06-01    256.139048
# 2020-07-01    257.775012
# 2020-08-01    258.599692
# 2020-09-01    259.018637
# 2020-10-01    258.984114
# 2020-11-01    258.869434
# 2020-12-01    259.033375
# 2021-01-01    260.232631
# 2021-02-01    261.758654
# 2021-03-01    263.767845
# 2021-04-01    265.937179
# 2021-05-01    268.131877
# 2021-06-01    270.607194
# 2021-07-01    271.780958
# 2021-08-01    272.263081
# 2021-09-01    272.767375
# 2021-10-01    274.932272
# 2021-11-01    276.283653
# 2021-12-01    277.081175
# Freq: MS, dtype: float64

# %%
r2_score = lr.score(x_test,y_test)
r2_score
# Out:
# 0.9987508596535536

# %%
plt.rcParams["figure.figsize"] = [10,7]
plt.plot(df['All items less food'], label='Train ')
plt.plot(y_test, label='Test ')
plt.plot(predictions, label='Predicted ')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### running another model

# %%
ppi = pd.read_csv('../CPI_Data/PPI_data.csv', index_col = 0).T[-120:]
ppi
# Out:
#            Final demand Final demand goods Final demand foods  \
# 2012-01-01        106.6              110.5              113.7
# 2012-02-01        107.1              111.1              113.6
# 2012-03-01        107.7              112.1              114.4
# 2012-04-01        108.0              112.3              114.5
# 2012-05-01        107.8              111.6              114.3
# ...                 ...                ...                ...
# 2021-08-01      128.755            128.296            133.625
# 2021-09-01      129.155            129.342            135.746
# 2021-10-01      130.128            130.767            135.016
# 2021-11-01      131.002            131.736            136.603
# 2021-12-01      130.956            130.941            136.156
#
#            Fresh fruits and melons Fresh and dry vegetables   Grains  \
# 2012-01-01                   117.6                    160.2    243.5
# 2012-02-01                   116.1                    148.6    241.6
# 2012-03-01                   115.4                    167.6    250.5
# 2012-04-01                   119.7                    157.8    242.3
# 2012-05-01                   111.2                    162.0    234.2
# ...                            ...                      ...      ...
# 2021-08-01                 139.955                  208.056  251.986
# 2021-09-01                 139.506                  249.151  223.168
# 2021-10-01                 139.661                  291.962  217.942
# 2021-11-01                 167.725                  325.555  232.633
# 2021-12-01                 158.535                  277.685  246.703
#
#            Eggs for fresh use Oilseeds Bakery products Milled rice  ...  \
# 2012-01-01              131.9    229.1           260.0       142.9  ...
# 2012-02-01              123.2    237.2           260.7       138.6  ...
# 2012-03-01              126.5    253.5           260.4       144.6  ...
# 2012-04-01              132.7    267.2           260.4       145.1  ...
# 2012-05-01              108.1    264.1           260.3       146.9  ...
# ...                       ...      ...             ...         ...  ...
# 2021-08-01            134.702  258.036         295.061     146.409  ...
# 2021-09-01            163.239  239.547          298.25      145.84  ...
# 2021-10-01            143.448  226.417         298.798     146.348  ...
# 2021-11-01            135.498  226.813         302.243     147.968  ...
# 2021-12-01            198.984  235.598         303.713     148.135  ...
#
#            Membership dues and admissions and recreation facility use fees (partial)  \
# 2012-01-01                                              105.4
# 2012-02-01                                              105.5
# 2012-03-01                                              105.8
# 2012-04-01                                              105.5
# 2012-05-01                                              105.6
# ...                                                       ...
# 2021-08-01                                            126.975
# 2021-09-01                                            126.496
# 2021-10-01                                            128.305
# 2021-11-01                                            129.409
# 2021-12-01                                            130.921
#
#            Recreational activity instruction fees (partial)  \
# 2012-01-01                                            107.4
# 2012-02-01                                            107.4
# 2012-03-01                                            107.4
# 2012-04-01                                            107.4
# 2012-05-01                                            107.4
# 2021-09-01                                            168.872        274.214
# 2021-10-01                                            170.986        276.590
# 2021-11-01                                            170.751        278.524
# 2021-12-01                                            167.052        280.126
#
#             Crude Oil Price  Gold US dollar per oz
# Date
# 2012-01-01           100.27                 1656.1
# 2012-02-01           102.20                 1742.6
# 2012-03-01           106.16                 1673.8
# 2012-04-01           103.32                 1650.1
# 2012-05-01            94.66                 1585.5
# ...                     ...                    ...
# 2021-08-01            67.73                 1784.0
# 2021-09-01            71.65                 1777.3
# 2021-10-01            81.48                 1776.9
# 2021-11-01            79.15                 1820.2
# 2021-12-01            71.71                 1786.7
#
# [120 rows x 316 columns]

# %%
gold_oil_x = cpi_gold_oil[['Food', 'Crude Oil Price', 'Gold US dollar per oz']]
gold_oil_x = gold_oil_x.join(ppi['Final demand'])

gold_oil_y = cpi_gold_oil['All items']

# %%
x_train, x_test, y_train, y_test = train_test_split(gold_oil_x, gold_oil_y, test_size = 0.2, shuffle = False)

# %%
# linear regression object
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x_test)

# %%
y_predict
# Out:
# array([258.41287935, 257.79512473, 258.25447678, 257.15100318,
#        258.22915638, 258.91484213, 260.11089071, 260.47498619,
#        260.90792346, 262.5411923 , 261.87773523, 262.02394661,
#        264.87727145, 266.48880883, 268.39595357, 271.22454754,
#        273.741773  , 275.98412387, 278.63395627, 280.76909664,
#        281.88261113, 283.92490598, 286.02263683, 286.50357001])

# %%
r2_score = lr.score(x_test,y_test)
r2_score
# Out:
# 0.6682681148128469

# %% [markdown]
# This is very odd, our model should not have such a high accuracy score.
#
# This may be because our model is overfitting.
#
# OR because there is a feature that is leaking information, giving the answer away.
#
# Reasons why it may ne overfitting..
# - using features that correlate greatly
# - giving model too many features
#
# What else can we do for extremely high accuracy scores?

# %% [markdown]
# look into why values are what they are and how theyre changing
# -external factors

# %%
# make dataframe just the major expenditure categories
df = df[['Food and beverages','Housing','Apparel','Transportation',
        'Medical care','Recreation','Education and communication',
        'Other goods and services']]

# %%
# create a function that checks correlation for all columns to get the best model columns
def evaluate_model(model, x, y):
    scores = []
    x = x.dropna()
    y = y.dropna()
    for x_column in x:
        y = y.drop(columns = [x_column], axis = 1)
        for y_column in y:
            x_train, x_test, y_train, y_test = train_test_split(x[[x_column]], y[y_column], random_state=1, test_size=0.2)
            model.fit(x_train, y_train)
            predict = model.predict(x_test)
            score = np.sqrt(metrics.mean_squared_error(predict, y_test))
            scores.append(score)
            index_name = x_column + ' ' + y_column
            print(f"The model {model} can predict {index_name} columns with root mean squared error of {score}")

# %%
Linear_Reg = LinearRegression()
evaluate_model(Linear_Reg, df, df)
# Out:
# The model LinearRegression() can predict Food and beverages Housing columns with root mean squared error of 4.802734802268778
# The model LinearRegression() can predict Food and beverages Apparel columns with root mean squared error of 3.109006378793539
# The model LinearRegression() can predict Food and beverages Transportation columns with root mean squared error of 13.020549468619
# The model LinearRegression() can predict Food and beverages Medical care columns with root mean squared error of 11.948399306573288
# The model LinearRegression() can predict Food and beverages Recreation columns with root mean squared error of 0.8592326847729517
# The model LinearRegression() can predict Food and beverages Education and communication columns with root mean squared error of 1.2894833481568584
# The model LinearRegression() can predict Food and beverages Other goods and services columns with root mean squared error of 5.742651230742322
# The model LinearRegression() can predict Housing Apparel columns with root mean squared error of 3.181903499429343
# The model LinearRegression() can predict Housing Transportation columns with root mean squared error of 13.234678845599298
# The model LinearRegression() can predict Housing Medical care columns with root mean squared error of 5.325488453938131
# The model LinearRegression() can predict Housing Recreation columns with root mean squared error of 0.9888417123518233
# The model LinearRegression() can predict Housing Education and communication columns with root mean squared error of 1.6521375833709444
# The model LinearRegression() can predict Housing Other goods and services columns with root mean squared error of 1.5862920266270206
# The model LinearRegression() can predict Apparel Transportation columns with root mean squared error of 13.341171740036131
# The model LinearRegression() can predict Apparel Medical care columns with root mean squared error of 29.587115765952504
# The model LinearRegression() can predict Apparel Recreation columns with root mean squared error of 2.97571630230594
# The model LinearRegression() can predict Apparel Education and communication columns with root mean squared error of 2.2095616522769705
# The model LinearRegression() can predict Apparel Other goods and services columns with root mean squared error of 21.552042636150503
# The model LinearRegression() can predict Transportation Medical care columns with root mean squared error of 40.53900323927968
# The model LinearRegression() can predict Transportation Recreation columns with root mean squared error of 3.5698286766603022
# The model LinearRegression() can predict Transportation Education and communication columns with root mean squared error of 2.737511938608331
# The model LinearRegression() can predict Transportation Other goods and services columns with root mean squared error of 28.139237275842152
# The model LinearRegression() can predict Medical care Recreation columns with root mean squared error of 1.2448721118650752
# The model LinearRegression() can predict Medical care Education and communication columns with root mean squared error of 1.6527667510104815
# The model LinearRegression() can predict Medical care Other goods and services columns with root mean squared error of 4.007484005511263
# The model LinearRegression() can predict Recreation Education and communication columns with root mean squared error of 1.6778287883987444
# The model LinearRegression() can predict Recreation Other goods and services columns with root mean squared error of 6.884754115368065
# The model LinearRegression() can predict Education and communication Other goods and services columns with root mean squared error of 16.29151235905803

# %% [markdown]
# Food and Beverage column with Recreation has the lowest RMSE score out of all

# %%
# run an accuracy score for the food and beverage column and recreation column
model = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(df[['Food and beverages']], df['Recreation'], random_state=1, test_size=0.2)
model.fit(x_train, y_train)
results = model.predict(x_test)
results
# Out:
# array([120.436951  , 117.4070011 , 117.37379549, 126.3140951 ,
#        118.84383051, 117.55754986, 116.46575925, 119.13868638,
#        117.65017605, 121.16522753, 120.95725552, 122.11820369,
#        113.77210982, 120.24795363, 124.42586907, 117.50137495,
#        122.71790208, 122.67895415, 118.14226828, 117.83143377,
#        123.94176616, 114.77526891, 119.34341272, 123.14757774])

# %%
r2_score = model.score(x_test,y_test)
r2_score
# Out:
# 0.9346923861630986

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(results, y_test)
# Out:
# 0.7382808065821345

# %% [markdown]
# We get an accuracy of 93% for our linear regression model using food and beverage with recreation categories.

# %%
plt.rcParams["figure.figsize"] = [10,7]
plt.plot( train[], label='Train '+str(i))
plt.plot(test[str(i)], label='Test '+str(i))
plt.plot(result[str(i)], label='Predicted '+str(i))
plt.legend(loc='best')
plt.show()
