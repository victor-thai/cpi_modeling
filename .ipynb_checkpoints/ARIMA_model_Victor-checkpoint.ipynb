# %% [markdown]
# # CPI ARIMA model

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
cpi = pd.read_csv('CPI_Data/Monthly_cpi_index.csv', index_col = 0)

#set index to datetime
cpi.index = pd.to_datetime(cpi.index, infer_datetime_format = True)
cpi
# Out:
#                Food  Food at home  Cereals and bakery products  \
# 2012-01-01  232.666       231.694                      266.677
# 2012-02-01  232.486       231.180                      267.821
# 2012-03-01  232.792       231.383                      267.101
# 2012-04-01  233.234       231.711                      268.014
# 2012-05-01  233.339       231.518                      268.653
# ...             ...           ...                          ...
# 2021-08-01  279.135       259.825                      288.990
# 2021-09-01  281.506       262.695                      292.069
# 2021-10-01  284.205       265.478                      294.625
# 2021-11-01  285.507       266.384                      295.909
# 2021-12-01  286.966       267.555                      297.279
#
#             Cereals and cereal products  Flour and prepared flour mixes  \
# 2012-01-01                      234.159                         252.159
# 2012-02-01                      233.362                         250.564
# 2012-03-01                      232.660                         252.104
# 2012-04-01                      233.662                         252.102
# 2012-05-01                      235.054                         254.336
# ...                                 ...                             ...
# 2021-08-01                      236.194                         248.823
# 2021-09-01                      236.183                         250.198
# 2021-10-01                      239.371                         249.956
# 2021-11-01                      241.091                         246.663
# 2021-12-01                      243.944                         248.322
#
#             Breakfast cereal  Rice, pasta, cornmeal  Bakery products    Bread  \
# 2012-01-01           228.664                242.992          283.880  170.658
# 2012-02-01           227.984                242.217          286.484  172.978
# 2012-03-01           227.997                238.975          285.771  172.955
# 2012-04-01           228.862                240.693          286.589  173.559
# 2012-05-01           230.326                241.615          286.629  173.581
# ...                      ...                    ...              ...      ...
# 2021-08-01           229.855                245.495          319.545  192.971
# 2021-09-01           229.122                245.890          324.458  196.492
# 2021-10-01           236.615                245.062          326.628  198.052
# 2021-11-01           238.343                248.552          327.648  200.415
# 2021-12-01           241.597                251.399          328.129  200.504
#
#             Fresh biscuits, rolls, muffins  ...  Transportation  \
# 2012-01-01                         167.911  ...         210.799
# 2012-02-01                         168.364  ...         214.429
# 2012-03-01                         168.406  ...         220.842
# 2012-04-01                         166.211  ...         223.083
# 2012-05-01                         167.158  ...         220.768
# ...                                    ...  ...             ...
# 2021-08-01                         186.280  ...         238.333
# 2021-09-01                         194.852  ...         236.373
# 2021-10-01                         195.203  ...         241.042
# 2021-11-01                         197.481  ...         245.532
# 2021-12-01                         194.413  ...         246.499
#
#             Private transportation  New and used motor vehicles  \
# 2012-01-01                 206.307                       99.659
# 2012-02-01                 210.013                       99.889
# 2012-03-01                 216.536                      100.325
# 2012-04-01                 218.563                      100.977
# 2012-05-01                 215.978                      101.399
# ...                            ...                          ...
# 2021-08-01                 237.994                      119.475
# 2021-09-01                 236.655                      117.947
# 2021-10-01                 241.413                      120.192
# 2021-11-01                 245.735                      122.436
# 2021-12-01                 246.999                      124.853
#
#             Utilities and public transportation  \
# 2012-01-01                              205.521
# 2012-02-01                              205.398
# 2012-03-01                              205.637
# 2012-04-01                              206.050
# 2012-05-01                              206.866
# ...                                         ...
# 2021-08-01                              229.805
# 2021-09-01                              229.568
# 2021-10-01                              231.301
# 2021-11-01                              231.880
# 2021-12-01                              231.516
#
#             Household furnishings and operations  Other goods and services  \
# 2012-01-01                               125.629                   391.382
# 2012-02-01                               126.180                   391.236
# 2012-03-01                               126.107                   392.364
# 2012-04-01                               126.114                   393.320
# 2012-05-01                               125.905                   392.859
# ...                                          ...                       ...
# 2021-08-01                               132.076                   479.048
# 2021-09-01                               133.462                   479.525
# 2021-10-01                               134.745                   483.592
# 2021-11-01                               135.345                   484.683
# 2021-12-01                               136.787                   487.131
#
#             Personal care  Recorded music and music subscriptions  \
# 2012-01-01        210.299                                  89.691
# 2012-02-01        210.330                                  89.896
# 2012-03-01        211.289                                  89.704
# 2012-04-01        211.865                                  89.084
# 2012-05-01        211.649                                  88.904
# ...                   ...                                     ...
# 2021-08-01        244.968                                  79.549
# 2021-09-01        244.840                                  79.820
# 2021-10-01        246.307                                  79.954
# 2021-11-01        246.445                                  79.385
# 2021-12-01        247.561                                  79.733
#
#             Men's underwear, nightwear, swimwear, and accessories  All items
# 2012-01-01                                            148.547        227.842
# 2012-02-01                                            148.183        228.329
# 2012-03-01                                            149.106        228.807
# 2012-04-01                                            150.584        229.187
# 2012-05-01                                            155.044        228.713
# ...                                                       ...            ...
# 2021-08-01                                            167.846        273.092
# 2021-09-01                                            168.872        274.214
# 2021-10-01                                            170.986        276.590
# 2021-11-01                                            170.751        278.524
# 2021-12-01                                            167.052        280.126
#
# [120 rows x 314 columns]

# %%
#there are some null values that we can't solve so will drop those categories
cpi = cpi.dropna(axis = 1)

# %%
cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 120 entries, 2012-01-01 to 2021-12-01
# Columns: 305 entries, Food to All items
# dtypes: float64(305)
# memory usage: 286.9 KB

# %% [markdown]
# ## Stationarity Check

# %% [markdown]
# Before running an ARIMA model, we must check for stationarity. A time series is stationary when the mean, variance, and covariance of the data are constant and not dependent on time.

# %%
# need to use statmodels decomposition
# decomposition is used to separate the data into potential seasonality, trend, and random residual

decomp = sm.tsa.seasonal_decompose(cpi["All items"], model = 'additive')
fig = decomp.plot()
plt.xlabel('Year')
plt.rcParams["figure.figsize"] = (20,10)
plt.show()

# %% [markdown]
# From looking at the core stationarity graphs, we do notice that there is prominent seasonality where there are consistent trends for it throughout the years. Along with that, residuals, which show how affected the data is, is easily affected where there is high variability among the data. The trend shows a linear trend that is representative of how our economy is where inflation exists and prices do essentially go up.
#
# This resource helped to understand what was going on: https://machinelearningmastery.com/decompose-time-series-data-trend-seasonality/

# %% [markdown]
# ## Dicky-Fuller Test

# %%
from statsmodels.tsa.stattools import adfuller

# %%
# function that tests stationarity with Dicky Fuller
def dicky_stationarity_test(data):
    
    #dynamic 12 month window rolling average and std
    moving_average = data.rolling(window = 12).mean()
    moving_std = data.rolling(window = 12).std()
    
    
    original_plot = plt.plot(data, label = 'original', color = 'black')
    mean_plot = plt.plot(moving_average, label = 'mean', color = 'blue')
    std_plot = plt.plot(moving_std, label = 'std', color = 'red')
    
    plt.legend(loc='best')
    plt.title('Rolling Average and Standard Deviation')
    plt.show(block = False)
    
    print('Dicky-Fuller Test results:')
    dftest = adfuller(data, autolag='AIC') #default autolag
    output = pd.Series(dftest[0:4], index=['Test Statistic','p-value','Number of Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        output['Critical Value (%s)'%key] = value
    print(output)

# %%
dicky_stationarity_test(cpi['All items'])
# Out:
# Dicky-Fuller Test results:
# Test Statistic                   3.207398
# p-value                          1.000000
# Number of Lags Used              2.000000
# Number of Observations Used    117.000000
# Critical Value (1%)             -3.487517
# Critical Value (5%)             -2.886578
# Critical Value (10%)            -2.580124
# dtype: float64

# %% [markdown]
# There is somewhat of a linear trend in our graph, since it is zoomed out, it is difficult to see whether or not there are fluctuations. There are some dips, but hard to tell where. Most of these dips are explored in EDA files for our project.
#
# The standard deviation is not very high so it stays near the zero y-axis.

# %%
# Augmented Dicky-Fuller test, gives p value  
dftest = adfuller(cpi['All items'], autolag='AIC') #default autolag
output = pd.Series(dftest[0:4], index=['Test Statistic','p-value','Number of Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    output['Critical Value (%s)'%key] = value
print(output)
# Out:
# Test Statistic                   3.207398
# p-value                          1.000000
# Number of Lags Used              2.000000
# Number of Observations Used    117.000000
# Critical Value (1%)             -3.487517
# Critical Value (5%)             -2.886578
# Critical Value (10%)            -2.580124
# dtype: float64

# %% [markdown]
# Since the test statistic is greater than the critical value (5%), this means that we fail to reject the null so the data is not stationary. This doesn't mean that we can't still run the model so we will continue.

# %% [markdown]
# ## Data preparation

# %% [markdown]
# There are three important parameters that need to be found in order for our model to be created.
#
# - p, parameter associated with the **Auto-Regressive** part
# - d, parameter for **Integration** part of model
# - q, parameter for **Moving Average** part of model
#
# But first, we have to fix the stationarity problem since it is not stationary before finding any parameters. This can be achieved by differencing. Differencing is used to remove the non-stationarity caused by the trend. The number of times that we have to do differencing is the parameter for d.
#
# - Differencing helps to stabilize the mean of the time series data so that there are no obvious trends.

# %%
# Differencing - remove non-stationarity.
plt.figure(figsize=(20, 10))

#doing difference twice here, this removes any stationary
cpi_diff = (((cpi.diff()).dropna()).diff()).dropna()

plt.xlabel('Year')
plt.ylabel('Consumer Price Index (differenced)')
plt.plot(cpi_diff['All items'])

# %%
#running decomp again to see the changes to stationarity
decomp = sm.tsa.seasonal_decompose(cpi_diff['All items'], model = 'additive')
fig = decomp.plot()
plt.xlabel('Year')
plt.rcParams["figure.figsize"] = (20,10)
plt.show()

# %% [markdown]
# The seasonal decomposition shows that there is no apparent trend anymore, the seasonality is still present, but the residuals are random now.

# %%
#run a dicky-fuller test again on new differenced data
dicky_stationarity_test(cpi_diff['All items'])
# Out:
# Dicky-Fuller Test results:
# Test Statistic                -6.949330e+00
# p-value                        9.784625e-10
# Number of Lags Used            5.000000e+00
# Number of Observations Used    1.120000e+02
# Critical Value (1%)           -3.490131e+00
# Critical Value (5%)           -2.887712e+00
# Critical Value (10%)          -2.580730e+00
# dtype: float64

# %% [markdown]
# After running Dicky-Fuller again, we can see that our test statistic is lower than our 5% critical value which means that we can reject the null and support the alternative. This means that we can assume our data is stationary now.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# Visualize the ACF (auto correlation function) and PACF (partial autocorrelation function)plots to 
# find parameters p and q, but on the differenced data since we need data to be stationary.
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,6))
plot_acf(cpi_diff['All items'], ax = ax1)
plot_pacf(cpi_diff['All items'], ax = ax2, method='ywmle')
plt.show()

# %%
# manually split the data in train and testing data samples
train = cpi.iloc[:96]
test = cpi.iloc[96::]

# %%
# need to import auto-arima which lets us do grid search for ARIMA model
from pmdarima.arima import auto_arima

# %% [markdown]
# In ARIMA models, must give the p,d,q values to the model, but using Auto ARIMA, it generates the best parameters for itself.

# %%
# do a grid search for our ARIMA model
grid_search = auto_arima(train['All items'], start_p=0, start_q=0, max_p=5, max_q=5, seasonal=False, d=2, D=0, 
                            trace=True, suppress_warnings=True, error_action='ignore', stepwise=True)
print(grid_search.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=150.669, Time=0.04 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=150.014, Time=0.02 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=148.669, Time=0.01 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 0.263 seconds
# 148.66892613701876

# %% [markdown]
# ## ARIMA model training

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
# fit the ARIMA model using the ARIMA package from statmodels, from parameters found using auto ARIMA
X = train['All items']
X.index = pd.DatetimeIndex(X.index.values, freq=X.index.inferred_freq) #inferred_freq: infer most likely frequency
model = ARIMA(X, order=(0, 2, 0))
model_fit = model.fit()

# %%
# look at summary of the model
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              All items   No. Observations:                   96
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                 -73.334
# Date:                Tue, 05 Apr 2022   AIC                            148.669
# Time:                        17:56:45   BIC                            151.212
# Sample:                    01-01-2012   HQIC                           149.696
#                          - 12-01-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.2787      0.026     10.883      0.000       0.229       0.329
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.73   Jarque-Bera (JB):                36.84
# Prob(Q):                              0.10   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.60   Skew:                             0.20
# Prob(H) (two-sided):                  0.16   Kurtosis:                         6.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# CRITIQUE THE MODEL AND ANALYZE NUMBERS!!!

# %%
# plot residuals to see how it is affected
plt.figure(figsize=(7, 4))
plt.plot(model_fit.resid)

# %% [markdown]
# ## Prediction with ARIMA model

# %%
train
# Out:
#                Food  Food at home  Cereals and bakery products  \
# 2012-01-01  232.666       231.694                      266.677
# 2012-02-01  232.486       231.180                      267.821
# 2012-03-01  232.792       231.383                      267.101
# 2012-04-01  233.234       231.711                      268.014
# 2012-05-01  233.339       231.518                      268.653
# ...             ...           ...                          ...
# 2019-08-01  258.410       241.153                      276.619
# 2019-09-01  258.943       241.543                      277.308
# 2019-10-01  259.632       242.340                      276.470
# 2019-11-01  259.467       241.726                      276.166
# 2019-12-01  259.823       241.750                      275.036
#
#             Cereals and cereal products  Flour and prepared flour mixes  \
# 2012-01-01                      234.159                         252.159
# 2012-02-01                      233.362                         250.564
# 2012-03-01                      232.660                         252.104
# 2012-04-01                      233.662                         252.102
# 2012-05-01                      235.054                         254.336
# ...                                 ...                             ...
# 2019-08-01                      228.385                         239.327
# 2019-09-01                      226.997                         238.686
# 2019-10-01                      226.009                         232.780
# 2019-11-01                      224.887                         224.422
# 2019-12-01                      224.896                         225.638
#
#             Breakfast cereal  Rice, pasta, cornmeal  Bakery products    Bread  \
# 2012-01-01           228.664                242.992          283.880  170.658
# 2012-02-01           227.984                242.217          286.484  172.978
# 2012-03-01           227.997                238.975          285.771  172.955
# 2012-04-01           228.862                240.693          286.589  173.559
# 2012-05-01           230.326                241.615          286.629  173.581
# ...                      ...                    ...              ...      ...
# 2019-08-01           220.688                240.329          304.417  182.235
# 2019-09-01           220.068                237.621          306.410  185.084
# 2019-10-01           220.408                236.496          305.674  185.162
# 2019-11-01           218.774                238.499          305.890  187.598
# 2019-12-01           221.618                234.282          304.051  186.499
#
#             Fresh biscuits, rolls, muffins  ...  Transportation  \
# 2012-01-01                         167.911  ...         210.799
# 2012-02-01                         168.364  ...         214.429
# 2012-03-01                         168.406  ...         220.842
# 2012-04-01                         166.211  ...         223.083
# 2012-05-01                         167.158  ...         220.768
# ...                                    ...  ...             ...
# 2019-08-01                         178.077  ...         211.084
# 2019-09-01                         179.626  ...         209.350
# 2019-10-01                         180.528  ...         210.487
# 2019-11-01                         180.255  ...         209.763
# 2019-12-01                         180.359  ...         208.482
#
#             Private transportation  New and used motor vehicles  \
# 2012-01-01                 206.307                       99.659
# 2012-02-01                 210.013                       99.889
# 2012-03-01                 216.536                      100.325
# 2012-04-01                 218.563                      100.977
# 2012-05-01                 215.978                      101.399
# ...                            ...                          ...
# 2019-08-01                 206.979                      100.407
# 2019-09-01                 205.068                       98.751
# 2019-10-01                 206.070                       98.684
# 2019-11-01                 205.317                       98.441
# 2019-12-01                 204.610                       98.495
#
#             Utilities and public transportation  \
# 2012-01-01                              205.521
# 2012-02-01                              205.398
# 2012-03-01                              205.637
# 2012-04-01                              206.050
# 2012-05-01                              206.866
# ...                                         ...
# 2019-08-01                              218.690
# 2019-09-01                              218.639
# 2019-10-01                              218.527
# 2019-11-01                              218.568
# 2019-12-01                              217.864
#
#             Household furnishings and operations  Other goods and services  \
# 2012-01-01                               125.629                   391.382
# 2012-02-01                               126.180                   391.236
# 2012-03-01                               126.107                   392.364
# 2012-04-01                               126.114                   393.320
# 2012-05-01                               125.905                   392.859
# ...                                          ...                       ...
# 2019-08-01                               123.818                   453.074
# 2019-09-01                               124.183                   453.193
# 2019-10-01                               124.256                   455.225
# 2019-11-01                               123.733                   456.262
# 2019-12-01                               123.462                   455.413
#
#             Personal care  Recorded music and music subscriptions  \
# 2012-01-01        210.299                                  89.691
# 2012-02-01        210.330                                  89.896
# 2012-03-01        211.289                                  89.704
# 2012-04-01        211.865                                  89.084
# 2012-05-01        211.649                                  88.904
# ...                   ...                                     ...
# 2019-08-01        234.749                                  82.332
# 2019-09-01        234.603                                  79.378
# 2019-10-01        235.578                                  80.003
# 2019-11-01        235.797                                  80.586
# 2019-12-01        235.310                                  80.141
#
#             Men's underwear, nightwear, swimwear, and accessories  All items
# 2012-01-01                                            148.547        227.842
# 2012-02-01                                            148.183        228.329
# 2012-03-01                                            149.106        228.807
# 2012-04-01                                            150.584        229.187
# 2012-05-01                                            155.044        228.713
# ...                                                       ...            ...
# 2019-08-01                                            157.029        256.179
# 2019-09-01                                            161.218        256.596
# 2019-10-01                                            159.172        257.305
# 2019-11-01                                            155.353        257.788
# 2019-12-01                                            151.248        258.263
#
# [96 rows x 305 columns]

# %%
model_fit.predict()
# Out:
# 2012-01-01      0.000000
# 2012-02-01    341.763016
# 2012-03-01    228.816000
# 2012-04-01    229.285000
# 2012-05-01    229.567000
#                  ...
# 2019-08-01    256.439000
# 2019-09-01    256.458000
# 2019-10-01    257.013000
# 2019-11-01    258.014000
# 2019-12-01    258.271000
# Freq: MS, Name: predicted_mean, Length: 96, dtype: float64

# %%
model_fit.forecast(8, alpha = .05)
# Out:
# 2020-01-01    258.738
# 2020-02-01    259.213
# 2020-03-01    259.688
# 2020-04-01    260.163
# 2020-05-01    260.638
# 2020-06-01    261.113
# 2020-07-01    261.588
# 2020-08-01    262.063
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
cpi.loc['2020-01-01':].index
# Out:
# DatetimeIndex(['2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
# use the testing data as a means of represent how accurate model is
ax = cpi['All items']['2012-01-01'::].plot(label='Observed')
forecast = model_fit.get_forecast()
forecast_summary = forecast.summary_frame()
forecast_data = model_fit.forecast(24, alpha = .05)
print(forecast_data)

#get the standard error and confidence interval
std_err, conf_int = forecast_summary['mean_se'], [forecast_summary['mean_ci_lower'], forecast_summary['mean_ci_upper']]
forecast = pd.DataFrame(forecast_data).set_index(cpi.loc['2020-01-01':].index)
forecast.plot(ax=ax, style = 'r', label='Forecast')

print(forecast_summary)

# Calculate and visualize the 95% confidence interval.
ax.fill_between(forecast.index, forecast_summary['mean_ci_lower'], forecast_summary['mean_ci_upper'], color='dimgray', alpha=0.1)

# # Add the labels to the plot.
plt.legend(('Observed', 'Forecast'))
plt.xlabel('Year')
plt.ylabel('Consumer Price Index')
# Out:
# 2020-01-01    258.738
# 2020-02-01    259.213
# 2020-03-01    259.688
# 2020-04-01    260.163
# 2020-05-01    260.638
# 2020-06-01    261.113
# 2020-07-01    261.588
# 2020-08-01    262.063
# 2020-09-01    262.538
# 2020-10-01    263.013
# 2020-11-01    263.488
# 2020-12-01    263.963
# 2021-01-01    264.438
# 2021-02-01    264.913
# 2021-03-01    265.388
# 2021-04-01    265.863
# 2021-05-01    266.338
# 2021-06-01    266.813
# 2021-07-01    267.288
# 2021-08-01    267.763
# 2021-09-01    268.238
# 2021-10-01    268.713
# 2021-11-01    269.188
# 2021-12-01    269.663
# Freq: MS, Name: predicted_mean, dtype: float64
# All items      mean   mean_se  mean_ci_lower  mean_ci_upper
# 2020-01-01  258.738  0.527935     257.703267     259.772733
# Text(0, 0.5, 'Consumer Price Index')

# %%
#accuracy score
from sklearn.metrics import mean_squared_error

print('All items RMSE: ' + str(mean_squared_error(forecast_data,test['All items'])))
# Out:
# All items RMSE: 19.78957016663411

# %% [markdown]
# Our base model of running it just on all items shows that there is going to somewhat of a linear trend. Researching more of why we are given this prediction, it is likely due to the data that we are giving the model to train it. When looking at the training data which is the blue line prior to the start of the red, there can definitely be a linear prediction trend.
#
# Then dip that starts at 2020 is due to the rise of the COVID pandemic where the economy did suffer, causing a decrease in the actual data. This could not be estimated by our model since this dip is not something that our model can predict.

# %% [markdown]
# ## ARIMA Testing with energy

# %% [markdown]
# ## Stationarity Check

# %% [markdown]
# Before running an ARIMA model, we must check for stationarity. A time series is stationary when the mean, variance, and covariance of the data are constant and not dependent on time.

# %%
# need to use statmodels decomposition
# decomposition is used to separate the data into potential seasonality, trend, and random residual

decomp = sm.tsa.seasonal_decompose(cpi["Energy"], model = 'additive')
fig = decomp.plot()
plt.xlabel('Year')
plt.rcParams["figure.figsize"] = (20,10)
plt.show()

# %% [markdown]
# From looking at the core stationarity graphs, we do notice that there is prominent seasonality where there are consistent trends for it throughout the years. Along with that, residuals, which show how affected the data is, is easily affected where there is high variability among the data. The trend shows a linear trend that is representative of how our economy is where inflation exists and prices do essentially go up.
#
# This resource helped to understand what was going on: https://machinelearningmastery.com/decompose-time-series-data-trend-seasonality/

# %% [markdown]
# ## Dicky-Fuller Test

# %%
from statsmodels.tsa.stattools import adfuller

# %%
# function that tests stationarity with Dicky Fuller
def dicky_stationarity_test(data):
    
    #dynamic 12 month window rolling average and std
    moving_average = data.rolling(window = 12).mean()
    moving_std = data.rolling(window = 12).std()
    
    
    original_plot = plt.plot(data, label = 'original', color = 'black')
    mean_plot = plt.plot(moving_average, label = 'mean', color = 'blue')
    std_plot = plt.plot(moving_std, label = 'std', color = 'red')
    
    plt.legend(loc='best')
    plt.title('Rolling Average and Standard Deviation')
    plt.show(block = False)
    
    print('Dicky-Fuller Test results:')
    dftest = adfuller(data, autolag='AIC') #default autolag
    output = pd.Series(dftest[0:4], index=['Test Statistic','p-value','Number of Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        output['Critical Value (%s)'%key] = value
    print(output)

# %%
dicky_stationarity_test(cpi['Energy'])
# Out:
# Dicky-Fuller Test results:
# Test Statistic                  -2.494355
# p-value                          0.116854
# Number of Lags Used              1.000000
# Number of Observations Used    118.000000
# Critical Value (1%)             -3.487022
# Critical Value (5%)             -2.886363
# Critical Value (10%)            -2.580009
# dtype: float64

# %% [markdown]
# There is somewhat of a linear trend in our graph, since it is zoomed out, it is difficult to see whether or not there are fluctuations. There are some dips, but hard to tell where. Most of these dips are explored in EDA files for our project.
#
# The standard deviation is not very high so it stays near the zero y-axis.

# %%
# Augmented Dicky-Fuller test, gives p value  
dftest = adfuller(cpi['Energy'], autolag='AIC') #default autolag
output = pd.Series(dftest[0:4], index=['Test Statistic','p-value','Number of Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    output['Critical Value (%s)'%key] = value
print(output)
# Out:
# Test Statistic                  -2.494355
# p-value                          0.116854
# Number of Lags Used              1.000000
# Number of Observations Used    118.000000
# Critical Value (1%)             -3.487022
# Critical Value (5%)             -2.886363
# Critical Value (10%)            -2.580009
# dtype: float64

# %% [markdown]
# Since the test statistic is greater than the critical value (5%), this means that we fail to reject the null so the data is not stationary. This doesn't mean that we can't still run the model so we will continue.

# %% [markdown]
# ## Data preparation

# %% [markdown]
# There are three important parameters that need to be found in order for our model to be created.
#
# - p, parameter associated with the **Auto-Regressive** part
# - d, parameter for **Integration** part of model
# - q, parameter for **Moving Average** part of model
#
# But first, we have to fix the stationarity problem since it is not stationary before finding any parameters. This can be achieved by differencing. Differencing is used to remove the non-stationarity caused by the trend. The number of times that we have to do differencing is the parameter for d.

# %%
# Differencing - remove non-stationarity.
plt.figure(figsize=(20, 10))

#doing difference twice here, this removes any stationary
# cpi_diff = (((cpi.diff()).dropna()).diff()).dropna()

plt.xlabel('Year')
plt.ylabel('Consumer Price Index (differenced)')
plt.plot(cpi_diff['Energy'])

# %%
#running decomp again to see the changes to stationarity
decomp = sm.tsa.seasonal_decompose(cpi_diff['Energy'], model = 'additive')
fig = decomp.plot()
plt.xlabel('Year')
plt.rcParams["figure.figsize"] = (20,10)
plt.show()

# %% [markdown]
# The seasonal decomposition shows that there is no apparent trend anymore, the seasonality is still present, but the residuals are random now.

# %%
#run a dicky-fuller test again on new differenced data
dicky_stationarity_test(cpi_diff['Energy'])
# Out:
# Dicky-Fuller Test results:
# Test Statistic                  -5.628825
# p-value                          0.000001
# Number of Lags Used             13.000000
# Number of Observations Used    104.000000
# Critical Value (1%)             -3.494850
# Critical Value (5%)             -2.889758
# Critical Value (10%)            -2.581822
# dtype: float64

# %% [markdown]
# After running Dicky-Fuller again, we can see that our test statistic is lower than our 5% critical value which means that we can reject the null and support the alternative. This means that we can assume our data is stationary now.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# Visualize the ACF (auto correlation function) and PACF (partial autocorrelation function)plots to 
# find parameters p and q, but on the differenced data since we need data to be stationary.
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,6))
plot_acf(cpi_diff['Energy'], ax = ax1)
plot_pacf(cpi_diff['Energy'], ax = ax2, method='ywmle')
plt.show()

# %%
# manually split the data in train and testing data samples
train = cpi.iloc[:96]
test = cpi.iloc[96::]

# %%
# need to import auto-arima which lets us do grid search for ARIMA model
from pmdarima.arima import auto_arima

# %% [markdown]
# In ARIMA models, must give the p,d,q values to the model, but using Auto ARIMA, it generates the best parameters for itself.

# %%
# do a grid search for our ARIMA model
grid_search = auto_arima(train['Energy'], start_p=0, start_q=0, max_p=5, max_q=5, seasonal=False, d=2, D=0, 
                            trace=True, suppress_warnings=True, error_action='ignore', stepwise=True)
print(grid_search.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=624.477, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=624.111, Time=0.12 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=621.640, Time=0.02 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=622.491, Time=0.01 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=619.676, Time=0.02 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(0,2,2)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=622.133, Time=0.01 sec
#  ARIMA(1,2,2)(0,0,0)[0]             : AIC=inf, Time=0.14 sec
#
# Best model:  ARIMA(0,2,1)(0,0,0)[0]
# Total fit time: 0.771 seconds
# 619.6758893619634

# %% [markdown]
# ## ARIMA model training

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
# fit the ARIMA model using the ARIMA package from statmodels, from parameters found using auto ARIMA
X = train['Energy']
X.index = pd.DatetimeIndex(X.index.values, freq=X.index.inferred_freq) #inferred_freq: infer most likely frequency
model = ARIMA(X, order=(0, 2, 1))
model_fit = model.fit()

# %%
# look at summary of the model
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Energy   No. Observations:                   96
# Model:                 ARIMA(0, 2, 1)   Log Likelihood                -307.838
# Date:                Tue, 05 Apr 2022   AIC                            619.676
# Time:                        17:56:06   BIC                            624.762
# Sample:                    01-01-2012   HQIC                           621.730
#                          - 12-01-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.3424      0.098     -3.505      0.000      -0.534      -0.151
# sigma2        40.8759      5.727      7.138      0.000      29.652      52.100
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.84   Jarque-Bera (JB):                 2.04
# Prob(Q):                              0.36   Prob(JB):                         0.36
# Heteroskedasticity (H):               0.72   Skew:                             0.34
# Prob(H) (two-sided):                  0.37   Kurtosis:                         3.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# CRITIQUE THE MODEL AND ANALYZE NUMBERS!!!

# %%
# plot residuals to see how it is affected
plt.figure(figsize=(7, 4))
plt.plot(model_fit.resid)

# %% [markdown]
# ## Prediction with ARIMA model

# %%
train['Energy']
# Out:
# 2012-01-01    236.942
# 2012-02-01    242.663
# 2012-03-01    253.599
# 2012-04-01    255.736
# 2012-05-01    250.306
#                ...
# 2019-08-01    216.978
# 2019-09-01    215.418
# 2019-10-01    216.351
# 2019-11-01    214.636
# 2019-12-01    212.982
# Freq: MS, Name: Energy, Length: 96, dtype: float64

# %%
model_fit.forecast(8, alpha = .05)
# Out:
# 2020-01-01    211.490797
# 2020-02-01    209.999593
# 2020-03-01    208.508390
# 2020-04-01    207.017186
# 2020-05-01    205.525983
# 2020-06-01    204.034780
# 2020-07-01    202.543576
# 2020-08-01    201.052373
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
cpi.loc['2020-01-01':].index
# Out:
# DatetimeIndex(['2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
# use the testing data as a means of represent how accurate model is
ax = cpi['Energy']['2012-01-01'::].plot(label='Observed')
forecast = model_fit.get_forecast()
forecast_summary = forecast.summary_frame()
forecast_data = model_fit.forecast(24, alpha = .05)
print(forecast_data)

#get the standard error and confidence interval
std_err, conf_int = forecast_summary['mean_se'], [forecast_summary['mean_ci_lower'], forecast_summary['mean_ci_upper']]
forecast = pd.DataFrame(forecast_data).set_index(cpi.loc['2020-01-01':].index)
forecast.plot(ax=ax, style = 'r', label='Forecast')

print(forecast_summary)

# Calculate and visualize the 95% confidence interval.
ax.fill_between(forecast.index, forecast_summary['mean_ci_lower'], forecast_summary['mean_ci_upper'], color='dimgray', alpha=0.15)

# # Add the labels to the plot.
plt.legend(('Observed', 'Forecast'))
plt.xlabel('Year')
plt.ylabel('Consumer Price Index')
# Out:
# 2020-01-01    211.490797
# 2020-02-01    209.999593
# 2020-03-01    208.508390
# 2020-04-01    207.017186
# 2020-05-01    205.525983
# 2020-06-01    204.034780
# 2020-07-01    202.543576
# 2020-08-01    201.052373
# 2020-09-01    199.561169
# 2020-10-01    198.069966
# 2020-11-01    196.578763
# 2020-12-01    195.087559
# 2021-01-01    193.596356
# 2021-02-01    192.105152
# 2021-03-01    190.613949
# 2021-04-01    189.122746
# 2021-05-01    187.631542
# 2021-06-01    186.140339
# 2021-07-01    184.649135
# 2021-08-01    183.157932
# 2021-09-01    181.666729
# 2021-10-01    180.175525
# 2021-11-01    178.684322
# 2021-12-01    177.193118
# Freq: MS, Name: predicted_mean, dtype: float64
# Energy            mean   mean_se  mean_ci_lower  mean_ci_upper
# 2020-01-01  211.490797  6.393423     198.959918     224.021675
# Text(0, 0.5, 'Consumer Price Index')

# %% [markdown]
# The predicted results are showing a linear trend for the energy CPI. This seems to be consistent among the ARIMA model that we have implemented. The results are always linear which is not entirely accurate.
